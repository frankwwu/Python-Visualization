# %%
# %env CATALYST_LOG_LEVEL = 15
# Out:
# env: CATALYST_LOG_LEVEL=15

# %%
# !pip install bokeh
# Out:
# ...
# distributed 1.21.8 requires msgpack, which is not installed.
# You are using pip version 10.0.1, however version 19.3.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
# !bokeh sampledata
# Out:
# Using data directory: C:\Users\frank\.bokeh\data
# Downloading: CGM.csv (1589982 bytes)
#
#      16384 [  1.03%]
#      32768 [  2.06%]
#      49152 [  3.09%]
#      65536 [  4.12%]
#      81920 [  5.15%]
#      98304 [  6.18%]
#     114688 [  7.21%]
#     131072 [  8.24%]
#     147456 [  9.27%]
#     163840 [ 10.30%]
#     180224 [ 11.33%]
#     196608 [ 12.37%]
#     212992 [ 13.40%]
#     229376 [ 14.43%]
#     245760 [ 15.46%]
#     262144 [ 16.49%]
#     278528 [ 17.52%]
#     294912 [ 18.55%]
#     311296 [ 19.58%]
#     327680 [ 20.61%]
#     344064 [ 21.64%]
#     360448 [ 22.67%]
#     376832 [ 23.70%]
#     393216 [ 24.73%]
#     409600 [ 25.76%]
#     425984 [ 26.79%]
#     442368 [ 27.82%]
#     458752 [ 28.85%]
#     475136 [ 29.88%]
#     491520 [ 30.91%]
#     507904 [ 31.94%]
#     524288 [ 32.97%]
#     540672 [ 34.00%]
#     557056 [ 35.04%]
#     573440 [ 36.07%]
#     589824 [ 37.10%]
#     606208 [ 38.13%]
#     622592 [ 39.16%]
#     638976 [ 40.19%]
# ...

# %%
from bokeh.io import output_notebook
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="a8b556c0-0f80-4b83-b544-5f83f0cafb69">Loading BokehJS ...</span>
#     </div>

# %%
import numpy as np

from bokeh.io import show
from bokeh.layouts import column
from bokeh.models import ColumnDataSource, RangeTool
from bokeh.plotting import figure
from bokeh.sampledata.stocks import AAPL, GOOG

dates_aapl = np.array(AAPL['date'], dtype=np.datetime64)
dates_goog = np.array(GOOG['date'], dtype=np.datetime64)
source_aapl = ColumnDataSource(data=dict(date=dates_aapl, close=AAPL['adj_close']))
source_goog = ColumnDataSource(data=dict(date=dates_goog, close=GOOG['adj_close']))

p = figure(plot_height=300, plot_width=800, tools="", toolbar_location=None,
           x_axis_type="datetime", x_range=(dates_aapl[1000], dates_aapl[2000]))

p.line('date', 'close', source=source_aapl, color='#33A55C')
p.line('date', 'close', source=source_goog, color='#FC7A79')
p.yaxis.axis_label = 'Price'
#p.legend.location = "top_left"

select = figure(plot_height=100, plot_width=800, y_range=p.y_range,
                x_axis_type="datetime", y_axis_type=None,
                tools="", toolbar_location=None)

range_rool = RangeTool(x_range=p.x_range)
range_rool.overlay.fill_color = "blue"
range_rool.overlay.fill_alpha = 0.2

select.line('date', 'close', source=source_aapl, color='#33A55C')
select.line('date', 'close', source=source_goog, color='#FC7A79')
select.ygrid.grid_line_color = None
select.add_tools(range_rool)
select.toolbar.active_multi = range_rool

show(column(p, select))
# Out:
#   <div class="bk-root" id="fd5fb4c4-7cdf-4b69-b7f1-8bd7d37cc305"></div>
